# %% [markdown]
# ## Faster interactive exploration of 1 billion points
# This example applies this `HilbertFrame2D` to the 1 billion point Open Street Maps dataset.
#
# First the dataset must be preprocessed.  This is an intesive operation that took ~18 minutes on a 2015 Macbook Pro with 16GB of RAM.  It also seems to require something like 20GB of free disk space available in order to perform the shuffle sort of the Hilbert distance index.

# %%
import dask
import datashader as ds
import datashader.transfer_functions as tf
import dask.dataframe as dd
import numpy as np
import hilbert_frame as hf

# %%
df = dd.io.parquet.read_parquet('../../../notebook/datashader_dev/datashader-examples/data/osm-1billion.snappy.parq/')

# %%
# %%time
# npartitions = df.npartitions
# p = 10 # 1024 x 1024 grid
# hframe = hf.HilbertFrame2D.from_dataframe(df=df,
#                                           dirname='osm-1billion.hframe',
#                                           x='x',
#                                           y='y',
#                                           p=p,
#                                           shuffle='disk',
#                                           compression='snappy',
#                                           engine='fastparquet',
#                                           npartitions=npartitions)

# %% [markdown]
# Load the `HilbertFrame2D` with `persist=True` to bring the dataframe into memory

# %%
hframe = hf.HilbertFrame2D(dirname='osm-1billion.hframe', persist=True)

# %% [markdown]
# Create a Bokeh `InteractiveImage` for exploring the dataset, and notice how much faster the render time is when zoomed in to detailed regions around the world.

# %%
bound = 20026376.39
bounds = dict(x_range = (-bound, bound), y_range = (int(-bound*0.4), int(bound*0.6)))
plot_width = 900
plot_height = int(plot_width*0.5)

# %%
def create_image(use_hilbert, x_range, y_range, w, h, name=None):
    cvs = ds.Canvas(plot_width=w, plot_height=h, x_range=x_range, y_range=y_range)
    df_cb = hframe.range_query(x_range, y_range)
    agg = cvs.points(df_cb, 'x', 'y', ds.count())
    img = tf.shade(agg)
    return img

# %%
from datashader.bokeh_ext import InteractiveImage
import bokeh.plotting as bp
from functools import partial

bp.output_notebook()
p = bp.figure(tools='pan,wheel_zoom,reset,box_zoom', x_range=bounds['x_range'], y_range=bounds['y_range'],
              plot_width=plot_width, plot_height=plot_height)

InteractiveImage(p, partial(create_image, True))
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1032">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="024cbdcd-4307-4e01-9e06-d8236db60b97"></div>
#
# <script type="text/javascript">
#   (function(root) {
#   function embed_document(root) {
#
#   var docs_json = {"110b88c7-7f50-41af-b658-58762a2cc339":{"roots":{"references":[{"attributes":{"below":[{"id":"1042","type":"LinearAxis"}],"left":[{"id":"1047","type":"LinearAxis"}],"plot_height":450,"plot_width":900,"renderers":[{"id":"1042","type":"LinearAxis"},{"id":"1046","type":"Grid"},{"id":"1047","type":"LinearAxis"},{"id":"1051","type":"Grid"},{"id":"1059","type":"BoxAnnotation"},{"id":"1067","type":"GlyphRenderer"}],"title":{"id":"1071","type":"Title"},"toolbar":{"id":"1056","type":"Toolbar"},"x_range":{"id":"1034","type":"Range1d"},"x_scale":{"id":"1038","type":"LinearScale"},"y_range":{"id":"1036","type":"Range1d"},"y_scale":{"id":"1040","type":"LinearScale"}},"id":"1033","subtype":"Figure","type":"Plot"},{"attributes":{"source":{"id":"1063","type":"ColumnDataSource"}},"id":"1068","type":"CDSView"},{"attributes":{},"id":"1054","type":"ResetTool"},{"attributes":{"dh":{"field":"dh","units":"data"},"dw":{"field":"dw","units":"data"},"image":{"field":"image"},"x":{"field":"x"},"y":{"field":"y"}},"id":"1065","type":"ImageRGBA"},{"attributes":{},"id":"1048","type":"BasicTicker"},{"attributes":{"formatter":{"id":"1072","type":"BasicTickFormatter"},"plot":{"id":"1033","subtype":"Figure","type":"Plot"},"ticker":{"id":"1048","type":"BasicTicker"}},"id":"1047","type":"LinearAxis"},{"attributes":{},"id":"1078","type":"Selection"},{"attributes":{"dh":{"field":"dh","units":"data"},"dw":{"field":"dw","units":"data"},"image":{"field":"image"},"x":{"field":"x"},"y":{"field":"y"}},"id":"1066","type":"ImageRGBA"},{"attributes":{"overlay":{"id":"1059","type":"BoxAnnotation"}},"id":"1055","type":"BoxZoomTool"},{"attributes":{"dimension":1,"plot":{"id":"1033","subtype":"Figure","type":"Plot"},"ticker":{"id":"1048","type":"BasicTicker"}},"id":"1051","type":"Grid"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"1059","type":"BoxAnnotation"},{"attributes":{},"id":"1053","type":"WheelZoomTool"},{"attributes":{},"id":"1052","type":"PanTool"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_multi":null,"active_scroll":"auto","active_tap":"auto","tools":[{"id":"1052","type":"PanTool"},{"id":"1053","type":"WheelZoomTool"},{"id":"1054","type":"ResetTool"},{"id":"1055","type":"BoxZoomTool"}]},"id":"1056","type":"Toolbar"},{"attributes":{"args":{"x_range":{"id":"1034","type":"Range1d"},"y_range":{"id":"1036","type":"Range1d"}},"code":"\n        // Define a callback to capture errors on the Python side\n        function callback(msg){\n          if (msg.msg_type == \"execute_result\") {\n            if (msg.content.data['text/plain'] === \"'Complete'\") {\n               if (Bokeh._queued.length) {\n                   update_plot();\n               } else {\n                   Bokeh._blocked = false;\n               }\n               Bokeh._timeout = Date.now();\n            }\n          } else {\n            console.log(\"Python callback returned unexpected message:\", msg)\n          }\n        }\n        callbacks = {iopub: {output: callback}};\n\n        function update_plot() {\n            range = Bokeh._queued;\n            var cmd = \"from datashader.bokeh_ext import InteractiveImage; InteractiveImage._callbacks['92137d4d-d976-4bd4-9ebb-5160233dc582'].update(\" + range + \")\"\n            // Execute the command on the Python kernel\n            if (IPython.notebook.kernel !== undefined) {\n                var kernel = IPython.notebook.kernel;\n                kernel.execute(cmd, callbacks, {silent : false});\n            }\n            Bokeh._queued = [];\n        }\n\n        var plot = x_range.plots[0];\n        // Generate a command to execute in Python\n        var ranges = {xmin: x_range.start,\n                       ymin: y_range.start,\n   ...
#   var render_items = [{"docid":"110b88c7-7f50-41af-b658-58762a2cc339","notebook_comms_target":"92137d4d-d976-4bd4-9ebb-5160233dc582","roots":{"1033":"024cbdcd-4307-4e01-9e06-d8236db60b97"}}];
#   root.Bokeh.embed.embed_items_notebook(docs_json, render_items);
#
#   }
#   if (root.Bokeh !== undefined) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (root.Bokeh !== undefined) {
#         embed_document(root);
#         clearInterval(timer);
#       }
#       attempts++;
#       if (attempts > 100) {
#         console.log("Bokeh: ERROR: Unable to run BokehJS code because BokehJS library is missing");
#         clearInterval(timer);
#       }
#     }, 10, root)
#   }
# })(window);
# </script>

# %% [markdown]
# ### Interaction GIF
# ![](osm-one-billion.gif)
